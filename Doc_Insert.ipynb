# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 13.3 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

#Establish connection to MongoDB
#Copy your own URI String to the row below
URI="mongodb+srv://eki:zzz@cluster0.zzzze.mongodb.net/?appName=Cluster0"
client = MongoClient(URI)

#Db and Collection
mydb = client["rag_docs"] # database
mycol = mydb["rag_docs"] # collection

f = open(r'Artificial_Intelligence.txt')  # open a file
text = f.read()    # read the entire contents, should be UTF-8 text

# build a document to be inserted
doc = {"file_name": "Cats_as_pets.txt", "contents" : text }
# insert the contents into the "file" collection
mycol.insert_one(doc)
# Out:
# InsertOneResult(ObjectId('69972114d44398c67d4ddd99'), acknowledged=True)
